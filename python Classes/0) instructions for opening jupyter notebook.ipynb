# %% [markdown]
# ## **Insructions for open  jupyter notebook**

# %% [markdown]
# 1). click windows button

# %% [markdown]
# ![image.png](attachment:5060fd23-7792-4ccc-b7b0-e5625d16ea55.png)

# %% [markdown]
# ## 2nd step
# - search termimal in search bar

# %% [markdown]
# ![Screenshot (7).png](attachment:4fc9be7c-cbc4-4735-86f6-65e63be8c462.png)

# %% [markdown]
# ## 3 rd step
# - type jupyter notebook in terminal

# %% [markdown]
# ![image.png](attachment:da6ec2ec-2d24-44bb-950e-49503a59fbde.png)

# %% [markdown]
# ## 4 th steps
#
# ![image.png](attachment:f49da3e0-a1c2-4c3c-98fd-2ec8bdb5f239.png)

# %% [markdown]
# ## 5th step
# ![image.png](attachment:05b84d47-bf76-44da-99a1-ec9bd2ee01a0.png)

# %% [markdown]
# ## 6 th step
# ![image.png](attachment:c2ab0b72-0d50-4bfd-97cc-d050f1b6d9c3.png)

# %%
gccb b grdc

# %%
Esc + a # this is for adding a new cell above selected cell
Esc + b # this is for adding a new cell below selected cell
Esc + m # markdown selected cell. This is used for we can wrirte the information or content
Esc + y # this command is used for re collect the cell
Esc + dd # If you want to delete cell, select that cell and press Esc + dd 
Ctrl + c # for copy 
ctrl + v # paste

# %% [markdown]
# ![image.png](attachment:e9ff4b8b-bb70-45cd-aac8-0df35350670e.png)

# %%
2 + 5
# Out:
# 7
